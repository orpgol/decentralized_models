# %%
# %matplotlib inline
import time
import random
from random import shuffle
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import pickle
from mpl_toolkits.axes_grid1 import ImageGrid
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
import itertools
import logging

import torch
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision
from torchvision import transforms, datasets, models
from torchvision.datasets import CIFAR10

from scipy.stats import entropy, ks_2samp
from scipy.special import kl_div
from sklearn import metrics
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import label_binarize

from torch.utils.tensorboard import SummaryWriter
# %load_ext tensorboard

import traceback
import copy

import pdb

# %%
logname = 'logs/stepwise_decentralized_multi_agent'
logging.basicConfig(filename=logname,
                            filemode='a',
                            format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                            datefmt='%H:%M:%S',
                            level=logging.DEBUG)

logging.info("Running Stepwise Decentralized Learning test")

logger = logging.getLogger('Decentralized_log')

# %%
np.random.seed(0)

# %%
# Transformations A
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Transformations B
RC   = transforms.RandomCrop(32, padding=4)
RHF  = transforms.RandomHorizontalFlip()
RVF  = transforms.RandomVerticalFlip()
NRM  = transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
TT   = transforms.ToTensor()
TPIL = transforms.ToPILImage()

# Transforms object for trainset with augmentation
transform_with_aug = transforms.Compose([TPIL, RC, RHF, TT, NRM])
# Transforms object for testset with NO augmentation
transform_no_aug   = transforms.Compose([TT, NRM])

# Downloading/Louding CIFAR10 data
trainset = torchvision.datasets.CIFAR10(root='../data/cifar10', train=True,
                                        download=True, transform=transform_train)

testset = torchvision.datasets.CIFAR10(root='../data/cifar10', train=False,
                                       download=True, transform=transform_test)

classDict = {'plane':0, 'car':1, 'bird':2, 'cat':3, 'deer':4, 'dog':5, 'frog':6, 'horse':7, 'ship':8, 'truck':9}

# Separating trainset/testset data/label
x_train  = trainset.data
x_test   = testset.data
y_train  = trainset.targets
y_test   = testset.targets

# Define a function to separate CIFAR classes by class index

def get_class_i(x, y, i):
    """
    x: trainset.train_data or testset.test_data
    y: trainset.train_labels or testset.test_labels
    i: class label, a number between 0 to 9
    return: x_i
    """
    # Convert to a numpy array
    y = np.array(y)
    # Locate position of labels that equal to i
    pos_i = np.argwhere(y == i)
    # Convert the result into a 1-D list
    pos_i = list(pos_i[:,0])
    # Collect all data that match the desired label
    x_i = [x[j] for j in pos_i]
    
    return x_i

class DatasetMaker(Dataset):
    def __init__(self, datasets, transformFunc = transform_no_aug):
        """
        datasets: a list of get_class_i outputs, i.e. a list of list of images for selected classes
        """
        self.datasets = datasets
        self.lengths  = [len(d) for d in self.datasets]
        self.transformFunc = transformFunc
    def __getitem__(self, i):
        class_label, index_wrt_class = self.index_of_which_bin(self.lengths, i)
        img = self.datasets[class_label][index_wrt_class]
        img = self.transformFunc(img)
        return img, class_label

    def __len__(self):
        return sum(self.lengths)
    
    def index_of_which_bin(self, bin_sizes, absolute_index, verbose=False):
        """
        Given the absolute index, returns which bin it falls in and which element of that bin it corresponds to.
        """
        # Which class/bin does i fall into?
        accum = np.add.accumulate(bin_sizes)
        if verbose:
            print("accum =", accum)
        bin_index  = len(np.argwhere(accum <= absolute_index))
        if verbose:
            print("class_label =", bin_index)
        # Which element of the fallent class/bin does i correspond to?
        index_wrt_class = absolute_index - np.insert(accum, 0, 0)[bin_index]
        if verbose:
            print("index_wrt_class =", index_wrt_class)

        return bin_index, index_wrt_class
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# If we are saving a fraction
frac = int(len(x_train) * 0.05)
x_reserve = x_train[:frac]
y_reserve = y_train[:frac]
x_train = x_train[frac:]
y_train = y_train[frac:]

# %%
# ================== Usage ================== #

# 
trainset1 = \
    DatasetMaker(
        [get_class_i(x_train, y_train, classDict['plane']), 
         get_class_i(x_train, y_train, classDict['car']), 
         get_class_i(x_train, y_train, classDict['bird']),
        [],[],[],[],[],[],[]],
        transform_with_aug
    )
trainset2 = \
    DatasetMaker(
        [[],[],[],
         get_class_i(x_train, y_train, classDict['cat']), 
         get_class_i(x_train, y_train, classDict['deer']), 
         get_class_i(x_train, y_train, classDict['dog']), 
         [],[],[],[]],
        transform_with_aug
    )
trainset3 = \
    DatasetMaker(
        [[],[],[],[],[],[],
         get_class_i(x_train, y_train, classDict['frog']), 
         get_class_i(x_train, y_train, classDict['horse']), 
         get_class_i(x_train, y_train, classDict['ship']), 
         get_class_i(x_train, y_train, classDict['truck'])],
        transform_with_aug
    )
trainset4 = \
    DatasetMaker(
        [get_class_i(x_train, y_train, classDict['plane']), 
         get_class_i(x_train, y_train, classDict['car']), 
         get_class_i(x_train, y_train, classDict['bird']), 
         get_class_i(x_train, y_train, classDict['cat']), 
         get_class_i(x_train, y_train, classDict['deer']),
         get_class_i(x_train, y_train, classDict['dog']), 
         get_class_i(x_train, y_train, classDict['frog']), 
         get_class_i(x_train, y_train, classDict['horse']), 
         get_class_i(x_train, y_train, classDict['ship']), 
         get_class_i(x_train, y_train, classDict['truck'])],
        transform_with_aug
    )
reserved = \
    DatasetMaker(
        [get_class_i(x_reserve, y_reserve, classDict['plane']), 
         get_class_i(x_reserve, y_reserve, classDict['car']), 
         get_class_i(x_reserve, y_reserve, classDict['bird']), 
         get_class_i(x_reserve, y_reserve, classDict['cat']), 
         get_class_i(x_reserve, y_reserve, classDict['deer']),
         get_class_i(x_reserve, y_reserve, classDict['dog']), 
         get_class_i(x_reserve, y_reserve, classDict['frog']), 
         get_class_i(x_reserve, y_reserve, classDict['horse']), 
         get_class_i(x_reserve, y_reserve, classDict['ship']), 
         get_class_i(x_reserve, y_reserve, classDict['truck'])],
        transform_with_aug
    )
testset  = \
    DatasetMaker(
        [get_class_i(x_test, y_test, classDict['plane']), 
         get_class_i(x_test, y_test, classDict['car']), 
         get_class_i(x_test, y_test, classDict['bird']), 
         get_class_i(x_test, y_test, classDict['cat']), 
         get_class_i(x_test, y_test, classDict['deer']),
         get_class_i(x_test, y_test, classDict['dog']), 
         get_class_i(x_test, y_test, classDict['frog']), 
         get_class_i(x_test, y_test, classDict['horse']), 
         get_class_i(x_test, y_test, classDict['ship']), 
         get_class_i(x_test, y_test, classDict['truck'])],
        transform_no_aug
    )

superset = torch.utils.data.ConcatDataset([trainset3,reserved])

kwargs = {'num_workers': 2, 'pin_memory': False}

# Create datasetLoaders from trainset and testset
trainsetLoader1   = DataLoader(trainset1, batch_size=64, shuffle=True , **kwargs)
trainsetLoader2   = DataLoader(trainset2, batch_size=64, shuffle=True , **kwargs)
trainsetLoader3   = DataLoader(trainset3, batch_size=64, shuffle=True , **kwargs)
trainsetLoader4   = DataLoader(trainset4, batch_size=64, shuffle=True , **kwargs)
reservedLoader    = DataLoader(superset, batch_size=64, shuffle=True , **kwargs)
testsetLoader    = DataLoader(testset , batch_size=64, shuffle=False, **kwargs)

# %%
def imshow(img):
    img = img / 2 + 0.3    # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
img, label = next(iter(reservedLoader))
imshow(torchvision.utils.make_grid(img))

# %%
device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(device)

# device2 = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Decentralized model using reserved data

# %% [markdown]
# ## Train a knowledge transfer model

# %%
def kaiming_init(m):
    if isinstance(m, (torch.nn.Linear, torch.nn.Conv2d)):
        torch.nn.init.sparse_(m.weight, sparsity=0.33)
        if m.bias is not None:
            m.bias.data.fill_(0)
    elif isinstance(m, (torch.nn.BatchNorm1d, torch.nn.BatchNorm2d)):
        m.weight.data.fill_(1)
        if m.bias is not None:
            m.bias.data.fill_(0)

class Decenter(torch.nn.Module):

    def __init__(self, shape):
        super(Decenter, self).__init__()
        if len(shape) == 1:
            shape = shape[0]
            self.dim = 0
        elif len(shape) == 2:
            shape = shape[1]
            self.dim = 1
        self.translation = torch.nn.Sequential(
#             torch.nn.Tanh(),
            torch.nn.Linear(shape*2, shape)
        )

#         self.weight_init()

    def weight_init(self):
        for block in self._modules:
            for m in self._modules[block]:
                kaiming_init(m)

    def forward(self, source, target):
        x = torch.cat((source, target), self.dim)
#         x = torch.cat((torch.flatten(source), torch.flatten(target)), 0)
#         x = torch.add(torch.flatten(source).to("cpu"), torch.flatten(target).to("cpu"))
        res = self.translation(x)
#         res = res.reshape(target.shape)
        return res
    
    
class Interpolate(torch.nn.Module):
    def __init__(self, size, mode):
        super(Interpolate, self).__init__()
        self.interp = torch.nn.functional.interpolate
        self.size = size
        self.mode = mode
        
    def forward(self, x):
        x = self.interp(x, size=self.size, mode=self.mode, align_corners=False)
        return x
    
class Reshape(torch.nn.Module):
    def __init__(self, *args):
        super(Reshape, self).__init__()
        self.shape = args

    def forward(self, x):
        return x.view(self.shape)
    
class Decenter_pooled(torch.nn.Module):

    def __init__(self, shape):
        super(Decenter_pooled, self).__init__()
        self.shape = shape
        self.translation = torch.nn.Sequential(
#             torch.nn.BatchNorm2d(channels_out),
            torch.nn.AdaptiveAvgPool2d(1),
#             Interpolate(size=1, mode='bilinear'),
            Reshape(shape[0], shape[1]*2),
            torch.nn.Linear(shape[1]*2, shape[1]*shape[-1]*shape[-1]),
#             Reshape(shape[0], shape[1] ,1 ,1),
        )

        self.weight_init()

    def weight_init(self):
        for block in self._modules:
            for m in self._modules[block]:
                kaiming_init(m)

    def forward(self, source, target):
        x = torch.cat((source, target), 1)
        res = self.translation(x)
        res = res.view(self.shape[0], self.shape[1], self.shape[2], self.shape[3])
        return res
    
    
class Decenter_conv(torch.nn.Module):

    def __init__(self, shape):
        super(Decenter_conv, self).__init__()
        channels_in = shape[1]*2
        channels_out = shape[1]
        self.translation = torch.nn.Sequential(
            torch.nn.BatchNorm2d(channels_in),
            torch.nn.Conv2d(channels_in, channels_out, 3, stride=1, padding=1)
#             torch.nn.ConvTranspose2d(channels_in, channels_out, 3, stride=1, padding=1)

        )

#         self.weight_init()

    def weight_init(self):
        for block in self._modules:
            for m in self._modules[block]:
                kaiming_init(m)

    def forward(self, source, target):
        x = torch.cat((source, target), 1)
#         x = torch.cat((torch.flatten(source), torch.flatten(target)), 0)
#         x = torch.add(torch.flatten(source).to("cpu"), torch.flatten(target).to("cpu"))
        res = self.translation(x)
        return res

# %%
grad_dict: dict = {}
def fc_hook(layer_name, grad_input, grad_output): 
    if layer_name not in grad_dict:
        grad_dict[layer_name] = {}
        grad_dict[layer_name]["grad_input"] = []
        grad_dict[layer_name]["grad_output"] = []
        grad_dict[layer_name]["labels"] = []
        
#     print(grad_input)
#     print(grad_output)
    grad_dict[layer_name]["grad_input"].append(grad_input[0].cpu().numpy())
    grad_dict[layer_name]["grad_output"].append(grad_output[0].cpu().numpy())
    
# def reserve_step(source, target):
    

matlst = []
fclst = []

def train_model(dataloders, model, criterion, optimizer, scheduler, num_epochs=25):
    writer = SummaryWriter('runs/') 

    since = time.time()
    use_gpu = torch.cuda.is_available()
    best_model_wts = 0.0
    best_acc = 0.0
    dataset_sizes = {'trainA': len(dataloders['trainA'].sampler),
                     'trainB': len(dataloders['trainB'].sampler),
                     'trainC': len(dataloders['trainC'].sampler),
                     'reservedA': len(dataloders['reservedA'].sampler),
                     'reservedB': len(dataloders['reservedB'].sampler),
                     'reservedCA': len(dataloders['reservedCA'].sampler),
                     'reservedCB': len(dataloders['reservedCB'].sampler),
                     'validA': len(dataloders['validA'].sampler),
                     'validB': len(dataloders['validB'].sampler),
                     'validC': len(dataloders['validC'].sampler)}

    i = 0
    ivc = 0
    runloss={'trainA':0.0, 'validA':0.0, 'trainB':0.0, 'validB':0.0, 'trainC':0.0, 'validC':0.0, 'reservedCA':0.0,'reservedCB':0.0}
    runcorrect={'trainA':0, 'validA':0, 'trainB':0, 'validB':0, 'trainC':0, 'validC':0, 'reservedCA':0, 'reservedCB':0}
    dload = {'trainA':iter(trainsetLoader1), 'trainB':iter(trainsetLoader2), 'trainC':iter(reservedLoader),
                'validA':iter(testsetLoader), 'validB':iter(testsetLoader), 'validC':iter(testsetLoader),
                'reservedA':iter(reservedLoader), 'reservedB':iter(reservedLoader), 'reservedCA':iter(reservedLoader), 'reservedCB':iter(reservedLoader)}
        
    for epoch in range(num_epochs):
        for phase in ['trainA', 'trainB', 'trainC','reservedCA','reservedCB']:
            model[phase].train(True)

            if phase in ['reservedCA','reservedCB']:
                if phase == 'reservedCA':
                    sd = model[phase].state_dict()
                    for key, value in mdlzAC.items():
                        shape = model['trainC'].state_dict()[key].shape
                        mdl = value[1](shape).to(device)
                        checkpoint = torch.load(value[0])
                        mdl.load_state_dict(checkpoint['model_state_dict'])

                        sd[key] = mdl(copy.deepcopy(model['trainA'].state_dict()[key]), copy.deepcopy(model['trainC'].state_dict()[key]))
#                         torch.save({'model_state_dict': mdl.state_dict()}, value[0])

#                         if key == 'conv1.weight':
#                             matlst.append(sd[key])
#                         elif key == 'fc.weight':
#                             fclst.append(sd[key])

                    model[phase].load_state_dict(sd)
                elif phase == 'reservedCB':
                    sd = model[phase].state_dict()
                    for key, value in mdlzBC.items():
                        shape = model['trainC'].state_dict()[key].shape
                        mdl = value[1](shape).to(device)
                        checkpoint = torch.load(value[0])
                        mdl.load_state_dict(checkpoint['model_state_dict'])

                        sd[key] = mdl(copy.deepcopy(model['trainB'].state_dict()[key]), copy.deepcopy(model['trainC'].state_dict()[key]))
#                         torch.save({'model_state_dict': mdl.state_dict()}, value[0])

#                         if key == 'conv1.weight':
#                             matlst.append(sd[key])
#                         elif key == 'fc.weight':
#                             fclst.append(sd[key])

#                     model[phase].load_state_dict(sd)
            try:
                inputs, labels = next(dload[phase])
            except:
                del dload[phase]
                dload[phase] = iter(dataloders[phase])
                inputs, labels = next(dload[phase])
            if use_gpu:
                inputs, labels = Variable(inputs.to(device)), Variable(labels.to(device))
            else:
                inputs, labels = Variable(inputs), Variable(labels)

            optimizer[phase].zero_grad()

            outputs = model[phase](inputs)
            _, preds = torch.max(outputs.data, 1)

            if phase in ['reservedCA','reservedCB']:
                loss_a = criterion['trainC'](outputs, labels)
#                     batch_size = labels.shape[0]
#                     # Dummy input that HAS to be 2D for the scatter (you can use view(-1,1) if needed)
#                     y = labels.reshape(-1,1)
#                     # One hot encoding buffer that you create out of the loop and just keep reusing
#                     y_onehot = torch.FloatTensor(batch_size, 10).to(device)

#                     # In your for loop
#                     y_onehot.zero_()
#                     y_onehot.scatter_(1, y, 1)

                if phase == 'reservedCA':
                    outputs2 = model['trainA'](inputs)
                elif phase == 'reservedCB':
                    outputs2 = model['trainB'](inputs)

                sm = torch.nn.Softmax(dim=1)
                outputs = sm(outputs)
                outputs2 = sm(outputs2)
                loss_b = criterion[phase](outputs, outputs2)
                loss = (loss_a + loss_b) / 2
            else:
                loss = criterion[phase](outputs, labels)

            loss.backward()
            optimizer[phase].step()

            if phase == 'reservedCA':
#                         loss_b.backward(retain_graph=False)
                for key, value in mdlzAC.items():
                    shape = model['trainC'].state_dict()[key].shape
                    mdl = value[1](shape).to(device)
                    opti = torch.optim.AdamW(mdl.parameters(), lr=0.001, betas=(0.9, 0.999))
                    checkpoint = torch.load(value[0])
                    mdl.load_state_dict(checkpoint['model_state_dict'])
                    mdl.train(True)
                    opti.load_state_dict(checkpoint['optimizer_state_dict'])
#                             opti.zero_grad()
                    opti.step()
                    torch.save({'model_state_dict': mdl.state_dict(),
                                'optimizer_state_dict': opti.state_dict(),
                                'factor': checkpoint['factor'],
                                'patience': checkpoint['patience'],
                                'scheduler_state_dict': checkpoint['scheduler_state_dict']},
                                value[0])

            elif phase == 'reservedCB':
#                         loss_b.backward(retain_graph=False)
                for key, value in mdlzBC.items():
                    shape = model['trainC'].state_dict()[key].shape
                    mdl = value[1](shape).to(device)
                    opti = torch.optim.AdamW(mdl.parameters(), lr=0.001, betas=(0.9, 0.999))
                    checkpoint = torch.load(value[0])
                    mdl.load_state_dict(checkpoint['model_state_dict'])
                    mdl.train(True)
                    opti.load_state_dict(checkpoint['optimizer_state_dict'])
#                             opti.zero_grad()
                    opti.step()
                    torch.save({'model_state_dict': mdl.state_dict(),
                                'optimizer_state_dict': opti.state_dict(),
                                'factor': checkpoint['factor'],
                                'patience': checkpoint['patience'],
                                'scheduler_state_dict': checkpoint['scheduler_state_dict']},
                                value[0])

#                     ## Tensorboard
#                     writer.add_histogram('distribution centers/resnet2', model['trainC'].fc.weight.cpu().detach().numpy(), i)

                ## Back prop hook
#                     grad_dict["fc"]["labels"].append(labels.cpu().numpy())
            runloss[phase] += loss.item()
            runcorrect[phase] += torch.sum(preds == labels.data).double().item()        
                
        if epoch%250 == 0:
            i+=1
            if phase == 'reservedCA':
                for key, value in mdlzAC.items():
                    checkpoint = torch.load(value[0])
                    sched = lr_scheduler.ReduceLROnPlateau(optimizerC, 'min', factor=checkpoint['factor'], patience=checkpoint['patience'])
                    sched.load_state_dict(checkpoint['scheduler_state_dict'])
                    sched.step(loss)
                    torch.save({'model_state_dict': checkpoint['model_state_dict'],
                                'optimizer_state_dict': checkpoint['optimizer_state_dict'],
                                'factor': checkpoint['factor'],
                                'patience': checkpoint['patience'],
                                'scheduler_state_dict': sched.state_dict()},
                                value[0])
            
            for phase in ['validA', 'validB', 'validC']:
                running_loss = 0.0
                running_corrects = 0
                if phase == 'validA':
                    train_epoch_loss = runloss['trainA']/(100*64)
                    train_epoch_acc = runcorrect['trainA']/(100*64)
                    model['trainA'].train(False)
                elif phase == 'validB':
                    train_epoch_loss = runloss['trainB']/(100*64)
                    train_epoch_acc = runcorrect['trainB']/(100*64)
                    model['trainB'].train(False)
                elif phase == 'validC':
                    train_epoch_loss = runloss['trainC']/(100*64)
                    train_epoch_acc = runcorrect['trainC']/(100*64)
                    model['trainC'].train(False)
                scheduler[phase].step(train_epoch_loss)
                
                for inputs, labels in dataloders[phase]:
                    if use_gpu:
                        inputs, labels = Variable(inputs.to(device)), Variable(labels.to(device))
                    else:
                        inputs, labels = Variable(inputs), Variable(labels)
                    optimizer[phase].zero_grad()
                    outputs = model[phase](inputs)
                    _, preds = torch.max(outputs.data, 1)
                
                    loss = criterion[phase](outputs, labels)    

                    running_loss += loss.item()
                    running_corrects += torch.sum(preds == labels.data)
            
                valid_epoch_loss = running_loss/dataset_sizes[phase]
                valid_epoch_acc = running_corrects.double()/dataset_sizes[phase]
                print('Epoch [{}/{}] phase: {} train loss: {:.4f} acc: {:.4f} ' 
                      'valid loss: {:.4f} acc: {:.4f}'.format(
                        epoch, num_epochs - 1,
                        phase,
                        train_epoch_loss, train_epoch_acc, 
                        valid_epoch_loss, valid_epoch_acc))
                print() 
                logger.info('Epoch [{}/{}] phase: {} train loss: {:.4f} acc: {:.4f} ' 
                      'valid loss: {:.4f} acc: {:.4f}'.format(
                        epoch, num_epochs - 1,
                        phase,
                        train_epoch_loss, train_epoch_acc, 
                        valid_epoch_loss, valid_epoch_acc))

                ## Writing to tensorboard
                if phase == 'validC':
                    writer.add_histogram('distribution centers/gossip', outputs, i)

                    writer.add_scalar('train/loss_gossip', train_epoch_loss, i)
                    writer.add_scalar('train/accuracy_gossip', train_epoch_acc, i)

                    writer.add_scalar('valid/loss_gossip', valid_epoch_loss, i)
                    writer.add_scalar('valid/accuracy_gossip', valid_epoch_acc, i)


            if phase in ['validA','validB','validC'] and valid_epoch_acc > best_acc:
                best_acc = valid_epoch_acc
                best_model_wts = model[phase].state_dict()
            runloss={'trainA':0.0, 'validA':0.0, 'trainB':0.0, 'validB':0.0, 'trainC':0.0, 'validC':0.0, 'reservedCA':0.0,'reservedCB':0.0}
            runcorrect={'trainA':0, 'validA':0, 'trainB':0, 'validB':0, 'trainC':0, 'validC':0, 'reservedCA':0, 'reservedCB':0}

        torch.cuda.empty_cache()       
    print('Best val Acc: {:4f}'.format(best_acc))
    logger.info('Best val Acc: {:4f}'.format(best_acc))

    writer.close()
#     model.load_state_dict(best_model_wts)
    return model

# %%
resnetA = models.resnet18(pretrained=False)
resnetB = models.resnet18(pretrained=False)
resnetC = models.resnet18(pretrained=False)
# freeze all model parameters
# for param in resnet.parameters():
#     param.requires_grad = False

# new final layer with 16 classes
num_ftrsA = resnetA.fc.in_features
resnetA.fc = torch.nn.Linear(num_ftrsA, 10)

num_ftrsB = resnetB.fc.in_features
resnetB.fc = torch.nn.Linear(num_ftrsB, 10)

num_ftrsC = resnetC.fc.in_features
resnetC.fc = torch.nn.Linear(num_ftrsC, 10)

def fc_backward_hook(module, grad_input, grad_output):  # module is Linear in this case. Ignored.
        fc_hook("fc", grad_input, grad_output)
resnetA.fc_hook_handle = resnetA.fc.register_backward_hook(fc_backward_hook)
resnetB.fc_hook_handle = resnetB.fc.register_backward_hook(fc_backward_hook)
resnetC.fc_hook_handle = resnetC.fc.register_backward_hook(fc_backward_hook)


def roc_auc_score_micro(y_pred_proba, y_true):
    y_pred_proba = y_pred_proba.detach().cpu()
    y_true = y_true.detach().cpu()
    return metrics.roc_auc_score(
        label_binarize(y_true, classes=list(range(y_pred_proba.shape[1]))).ravel(),
        y_pred_proba.flatten())


resnetA = resnetA.to(device)
resnetB = resnetB.to(device)
resnetC = resnetC.to(device)

criterionA = torch.nn.CrossEntropyLoss()
# criterionB = torch.nn.CrossEntropyLoss()
# criterionA = torch.nn.KLDivLoss()
criterionB = torch.nn.KLDivLoss(reduction = 'batchmean')
# criterionB = torch.nn.KLDivLoss(reduction = 'mean')
# criterionB = torch.nn.MSELoss()
# optimizerA = torch.optim.SGD(resnetA.parameters(), lr=0.001, momentum=0.9)
# optimizerB = torch.optim.SGD(resnetB.parameters(), lr=0.001, momentum=0.9)
optimizerA = torch.optim.AdamW(resnetA.parameters(), lr=0.001, betas=(0.9, 0.999))
optimizerB = torch.optim.AdamW(resnetB.parameters(), lr=0.001, betas=(0.9, 0.999))
optimizerC = torch.optim.AdamW(resnetC.parameters(), lr=0.001, betas=(0.9, 0.999))

# exp_lr_schedulerA = lr_scheduler.StepLR(optimizerA, step_size=20, gamma=0.1)
# exp_lr_schedulerB = lr_scheduler.StepLR(optimizerB, step_size=20, gamma=0.1)
# exp_lr_schedulerC = lr_scheduler.StepLR(optimizerC, step_size=20, gamma=0.1)
exp_lr_schedulerA = lr_scheduler.ReduceLROnPlateau(optimizerA, 'min', factor=0.90, patience=5)
exp_lr_schedulerB = lr_scheduler.ReduceLROnPlateau(optimizerB, 'min', factor=0.90, patience=5)
exp_lr_schedulerC = lr_scheduler.ReduceLROnPlateau(optimizerC, 'min', factor=0.90, patience=5)


def hwout(Hin, padding, dilation, kernel_size, stride):
    return (Hin + 2 * padding - dilation * (kernel_size-1) - 1)/stride + 1

# %%
max_layer = 0
max_neurons = 0
for prm in resnetC.named_parameters():
    num_ftr = np.prod(prm[1].shape)
    if num_ftr > max_neurons:
         max_neurons = num_ftr
         max_layer = prm[1]

# %%
[x[0] for x in resnetC.named_parameters()]
# Out:
# ['conv1.weight',
#  'bn1.weight',
#  'bn1.bias',
#  'layer1.0.conv1.weight',
#  'layer1.0.bn1.weight',
#  'layer1.0.bn1.bias',
#  'layer1.0.conv2.weight',
#  'layer1.0.bn2.weight',
#  'layer1.0.bn2.bias',
#  'layer1.1.conv1.weight',
#  'layer1.1.bn1.weight',
#  'layer1.1.bn1.bias',
#  'layer1.1.conv2.weight',
#  'layer1.1.bn2.weight',
#  'layer1.1.bn2.bias',
#  'layer2.0.conv1.weight',
#  'layer2.0.bn1.weight',
#  'layer2.0.bn1.bias',
#  'layer2.0.conv2.weight',
#  'layer2.0.bn2.weight',
#  'layer2.0.bn2.bias',
#  'layer2.0.downsample.0.weight',
#  'layer2.0.downsample.1.weight',
#  'layer2.0.downsample.1.bias',
#  'layer2.1.conv1.weight',
#  'layer2.1.bn1.weight',
#  'layer2.1.bn1.bias',
#  'layer2.1.conv2.weight',
#  'layer2.1.bn2.weight',
#  'layer2.1.bn2.bias',
#  'layer3.0.conv1.weight',
#  'layer3.0.bn1.weight',
#  'layer3.0.bn1.bias',
#  'layer3.0.conv2.weight',
#  'layer3.0.bn2.weight',
#  'layer3.0.bn2.bias',
#  'layer3.0.downsample.0.weight',
#  'layer3.0.downsample.1.weight',
#  'layer3.0.downsample.1.bias',
#  'layer3.1.conv1.weight',
#  'layer3.1.bn1.weight',
#  'layer3.1.bn1.bias',
#  'layer3.1.conv2.weight',
#  'layer3.1.bn2.weight',
#  'layer3.1.bn2.bias',
#  'layer4.0.conv1.weight',
#  'layer4.0.bn1.weight',
#  'layer4.0.bn1.bias',
#  'layer4.0.conv2.weight',
#  'layer4.0.bn2.weight',
#  'layer4.0.bn2.bias',
#  'layer4.0.downsample.0.weight',
#  'layer4.0.downsample.1.weight',
#  'layer4.0.downsample.1.bias',
#  'layer4.1.conv1.weight',
#  'layer4.1.bn1.weight',
#  'layer4.1.bn1.bias',
#  'layer4.1.conv2.weight',
#  'layer4.1.bn2.weight',
#  'layer4.1.bn2.bias',
#  'fc.weight',
#  'fc.bias']

# %%
# %%timeit
mdlzAC = dict()
mdlzBC = dict()
params = []
model_dir = './stepwise_model_chain'
conv_layers = ['layer4.1.conv1.weight', 'layer4.0.conv1.weight']
bn_layers = ['fc.weight']

for prm in resnetC.named_parameters():
# for prm in temp_list:
#     if 'conv' in prm[0] or 'fc' in prm[0] or 'bn' in prm[0] or 'downsample' in prm[0]:
    if prm[0] in bn_layers+conv_layers:
        try:
            if prm[1].dim() > 2:
#                 if prm[0] not in conv_layers:
#                     continue
                mdl = Decenter_conv(prm[1].shape).to(device)
                optimizer = torch.optim.AdamW(mdl.parameters(), lr=0.1, betas=(0.9, 0.999))
                exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5)
                torch.save({'model_state_dict': mdl.state_dict(),
                            'optimizer_state_dict': optimizer.state_dict(),
                            'factor': 0.1,
                            'patience': 5,
                            'scheduler_state_dict': exp_lr_scheduler.state_dict()},
                           model_dir + '/' + prm[0]+'A')
                torch.save({'model_state_dict': mdl.state_dict(),
                            'optimizer_state_dict': optimizer.state_dict(),
                            'factor': 0.1,
                            'patience': 5,
                            'scheduler_state_dict': exp_lr_scheduler.state_dict()},
                           model_dir + '/' + prm[0]+'B')
                mdlzAC[prm[0]] = (model_dir + '/' + prm[0]+'A', Decenter_conv)
                mdlzBC[prm[0]] = (model_dir + '/' + prm[0]+'B', Decenter_conv)
#                 params += mdl.parameters()
#                 pass
            else:
#                 if prm[0] not in bn_layers:
#                     continue
                mdl = Decenter(prm[1].shape).to(device)
                optimizer = torch.optim.AdamW(mdl.parameters(), lr=0.1, betas=(0.9, 0.999))
                exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=1)
                torch.save({'model_state_dict': mdl.state_dict(),
                            'optimizer_state_dict': optimizer.state_dict(),
                            'factor': 0.5,
                            'patience': 1,
                            'scheduler_state_dict': exp_lr_scheduler.state_dict()},
                           model_dir + '/' + prm[0]+'A')
                torch.save({'model_state_dict': mdl.state_dict(),
                            'optimizer_state_dict': optimizer.state_dict(),
                            'factor': 0.5,
                            'patience': 1,
                            'scheduler_state_dict': exp_lr_scheduler.state_dict()},
                           model_dir + '/' + prm[0]+'B')
                mdlzAC[prm[0]] = (model_dir + '/' + prm[0]+'A', Decenter)
                mdlzBC[prm[0]] = (model_dir + '/' + prm[0]+'B', Decenter)
#                 params += mdl.parameters()
            
            del mdl
            torch.cuda.empty_cache()
        except Exception as e:
            print("Problem with: " + prm[0] + " Size: " + str(num_ftr))
            print("Error: " + str(e))
            traceback.print_exc()
            print()
            pass
        
# params += list(resnetC.parameters())

# optimizerRB = torch.optim.SGD(params, lr=0.01, momentum=0.9)
optimizerRC = torch.optim.AdamW(resnetC.parameters(), lr=0.001, betas=(0.9, 0.999))

# %%
mdlzBC
# Out:
# {'layer4.0.conv1.weight': ('./stepwise_model_chain/layer4.0.conv1.weightB',
#   __main__.Decenter_conv),
#  'layer4.1.conv1.weight': ('./stepwise_model_chain/layer4.1.conv1.weightB',
#   __main__.Decenter_conv),
#  'fc.weight': ('./stepwise_model_chain/fc.weightB', __main__.Decenter)}

# %%
### Define phases 
dloaders = {'trainA':trainsetLoader1, 'trainB':trainsetLoader2, 'trainC':reservedLoader,
            'validA':testsetLoader, 'validB':testsetLoader, 'validC':testsetLoader,
            'reservedA':reservedLoader, 'reservedB':reservedLoader, 'reservedCA':reservedLoader, 'reservedCB':reservedLoader}
model = {'trainA':resnetA, 'trainB':resnetB, 'trainC':resnetC,
         'validA':resnetA, 'validB':resnetB, 'validC':resnetC,
         'reservedA':resnetA, 'reservedB':resnetB, 'reservedCA':resnetC, 'reservedCB':resnetC}
optimizer = {'trainA':optimizerA, 'trainB':optimizerB, 'trainC':optimizerC,
             'validA':optimizerA, 'validB':optimizerB, 'validC':optimizerC,
             'reservedA':optimizerA, 'reservedB':optimizerB, 'reservedCA':optimizerRC, 'reservedCB':optimizerRC}
criterion = {'trainA':criterionA, 'trainB':criterionA, 'trainC':criterionA,
             'validA':criterionA, 'validB':criterionA, 'validC':criterionA,
             'reservedA':criterionB, 'reservedB':criterionB, 'reservedCA':criterionB, 'reservedCB':criterionB}
exp_lr_scheduler = {'trainA':exp_lr_schedulerA, 'trainB':exp_lr_schedulerB, 'trainC':exp_lr_schedulerC,
             'validA':exp_lr_schedulerA, 'validB':exp_lr_schedulerB, 'validC':exp_lr_schedulerC,
             'reservedA':exp_lr_schedulerA, 'reservedB':exp_lr_schedulerB, 'reservedCA':exp_lr_schedulerC, 'reservedCB':exp_lr_schedulerC}

# %%
logging.info("#### bn acti conv and fc - unlimited bn - adam learning rate 0.001 - scheduler 20 - opt adamw ####")

start_time = time.time()
model = train_model(dloaders, model, criterion, optimizer, exp_lr_scheduler, num_epochs=81*250)
print('Training time: {:10f} minutes'.format((time.time()-start_time)/60))
# Out:
# Epoch [0/20249] phase: validA train loss: 0.0004 acc: 0.0025 valid loss: 0.0363 acc: 0.1202
#
# Epoch [0/20249] phase: validB train loss: 0.0004 acc: 0.0016 valid loss: 0.0362 acc: 0.1173
#
# Epoch [0/20249] phase: validC train loss: 0.0004 acc: 0.0006 valid loss: 0.0377 acc: 0.1040
#
# Epoch [250/20249] phase: validA train loss: 0.0251 acc: 1.8564 valid loss: 0.1265 acc: 0.2495
#
# Epoch [250/20249] phase: validB train loss: 0.0373 acc: 1.3700 valid loss: 0.1178 acc: 0.1838
#
# Epoch [250/20249] phase: validC train loss: 0.0326 acc: 1.8505 valid loss: 0.0285 acc: 0.3887
#
# Epoch [500/20249] phase: validA train loss: 0.0182 acc: 2.0322 valid loss: 0.1307 acc: 0.2581
#
# Epoch [500/20249] phase: validB train loss: 0.0323 acc: 1.5402 valid loss: 0.1200 acc: 0.1850
#
# Epoch [500/20249] phase: validC train loss: 0.0224 acc: 2.0667 valid loss: 0.0285 acc: 0.4224
#
# Epoch [750/20249] phase: validA train loss: 0.0160 acc: 2.0994 valid loss: 0.1399 acc: 0.2581
#
# Epoch [750/20249] phase: validB train loss: 0.0299 acc: 1.6267 valid loss: 0.1321 acc: 0.1922
#
# Epoch [750/20249] phase: validC train loss: 0.0199 acc: 2.1063 valid loss: 0.0254 acc: 0.4730
#
# Epoch [1000/20249] phase: validA train loss: 0.0142 acc: 2.1455 valid loss: 0.1328 acc: 0.2620
#
# Epoch [1000/20249] phase: validB train loss: 0.0277 acc: 1.7073 valid loss: 0.1276 acc: 0.2041
#
# Epoch [1000/20249] phase: validC train loss: 0.0177 acc: 2.1409 valid loss: 0.0243 acc: 0.5037
#
# Epoch [1250/20249] phase: validA train loss: 0.0131 acc: 2.1752 valid loss: 0.1550 acc: 0.2660
#
# Epoch [1250/20249] phase: validB train loss: 0.0263 acc: 1.7550 valid loss: 0.1392 acc: 0.2089
#
# Epoch [1250/20249] phase: validC train loss: 0.0158 acc: 2.1819 valid loss: 0.0247 acc: 0.5187
#
# Epoch [1500/20249] phase: validA train loss: 0.0121 acc: 2.1905 valid loss: 0.1516 acc: 0.2668
#
# Epoch [1500/20249] phase: validB train loss: 0.0253 acc: 1.7973 valid loss: 0.1298 acc: 0.2141
#
# Epoch [1500/20249] phase: validC train loss: 0.0149 acc: 2.2000 valid loss: 0.0222 acc: 0.5479
#
# Epoch [1750/20249] phase: validA train loss: 0.0108 acc: 2.2281 valid loss: 0.1476 acc: 0.2720
#
# Epoch [1750/20249] phase: validB train loss: 0.0238 acc: 1.8481 valid loss: 0.1269 acc: 0.2142
#
# Epoch [1750/20249] phase: validC train loss: 0.0138 acc: 2.2202 valid loss: 0.0238 acc: 0.5448
#
# Epoch [2000/20249] phase: validA train loss: 0.0105 acc: 2.2403 valid loss: 0.1637 acc: 0.2697
#
# Epoch [2000/20249] phase: validB train loss: 0.0230 acc: 1.8670 valid loss: 0.1458 acc: 0.2284
#
# Epoch [2000/20249] phase: validC train loss: 0.0125 acc: 2.2472 valid loss: 0.0212 acc: 0.5844
#
# Epoch [2250/20249] phase: validA train loss: 0.0100 acc: 2.2491 valid loss: 0.1569 acc: 0.2692
#
# Epoch [2250/20249] phase: validB train loss: 0.0221 acc: 1.8923 valid loss: 0.1412 acc: 0.2123
#
# Epoch [2250/20249] phase: validC train loss: 0.0117 acc: 2.2525 valid loss: 0.0217 acc: 0.5789
#
# Epoch [2500/20249] phase: validA train loss: 0.0096 acc: 2.2644 valid loss: 0.1626 acc: 0.2733
#
# Epoch [2500/20249] phase: validB train loss: 0.0214 acc: 1.9181 valid loss: 0.1497 acc: 0.2283
#
# Epoch [2500/20249] phase: validC train loss: 0.0109 acc: 2.2697 valid loss: 0.0222 acc: 0.5756
#
# Epoch [2750/20249] phase: validA train loss: 0.0089 acc: 2.2744 valid loss: 0.1661 acc: 0.2726
#
# Epoch [2750/20249] phase: validB train loss: 0.0205 acc: 1.9475 valid loss: 0.1471 acc: 0.2308
#
# Epoch [2750/20249] phase: validC train loss: 0.0102 acc: 2.2880 valid loss: 0.0217 acc: 0.6035
#
# Epoch [3000/20249] phase: validA train loss: 0.0086 acc: 2.2903 valid loss: 0.1733 acc: 0.2719
#
# Epoch [3000/20249] phase: validB train loss: 0.0202 acc: 1.9536 valid loss: 0.1523 acc: 0.2246
#
# Epoch [3000/20249] phase: validC train loss: 0.0093 acc: 2.3095 valid loss: 0.0231 acc: 0.5912
#
# Epoch [3250/20249] phase: validA train loss: 0.0079 acc: 2.3061 valid loss: 0.1697 acc: 0.2761
#
# Epoch [3250/20249] phase: validB train loss: 0.0189 acc: 1.9944 valid loss: 0.1432 acc: 0.2341
#
# Epoch [3250/20249] phase: validC train loss: 0.0088 acc: 2.3175 valid loss: 0.0214 acc: 0.6142
#
# Epoch [3500/20249] phase: validA train loss: 0.0077 acc: 2.3122 valid loss: 0.1647 acc: 0.2775
#
# Epoch [3500/20249] phase: validB train loss: 0.0188 acc: 2.0011 valid loss: 0.1438 acc: 0.2339
#
# Epoch [3500/20249] phase: validC train loss: 0.0081 acc: 2.3275 valid loss: 0.0205 acc: 0.6332
#
# Epoch [3750/20249] phase: validA train loss: 0.0072 acc: 2.3194 valid loss: 0.1753 acc: 0.2738
#
# Epoch [3750/20249] phase: validB train loss: 0.0183 acc: 2.0183 valid loss: 0.1426 acc: 0.2329
#
# Epoch [3750/20249] phase: validC train loss: 0.0081 acc: 2.3280 valid loss: 0.0206 acc: 0.6383
#
# Epoch [4000/20249] phase: validA train loss: 0.0071 acc: 2.3219 valid loss: 0.1967 acc: 0.2786
#
# Epoch [4000/20249] phase: validB train loss: 0.0177 acc: 2.0294 valid loss: 0.1461 acc: 0.2383
#
# Epoch [4000/20249] phase: validC train loss: 0.0072 acc: 2.3508 valid loss: 0.0217 acc: 0.6313
#
# Epoch [4250/20249] phase: validA train loss: 0.0069 acc: 2.3297 valid loss: 0.1850 acc: 0.2741
#
# Epoch [4250/20249] phase: validB train loss: 0.0175 acc: 2.0361 valid loss: 0.1456 acc: 0.2352
#
# Epoch [4250/20249] phase: validC train loss: 0.0069 acc: 2.3553 valid loss: 0.0249 acc: 0.6106
#
# Epoch [4500/20249] phase: validA train loss: 0.0068 acc: 2.3278 valid loss: 0.1805 acc: 0.2752
#
# Epoch [4500/20249] phase: validB train loss: 0.0167 acc: 2.0606 valid loss: 0.1566 acc: 0.2428
#
# Epoch [4500/20249] phase: validC train loss: 0.0066 acc: 2.3606 valid loss: 0.0235 acc: 0.6156
#
# Epoch [4750/20249] phase: validA train loss: 0.0061 acc: 2.3498 valid loss: 0.1791 acc: 0.2803
#
# Epoch [4750/20249] phase: validB train loss: 0.0162 acc: 2.0705 valid loss: 0.1455 acc: 0.2398
#
# Epoch [4750/20249] phase: validC train loss: 0.0062 acc: 2.3717 valid loss: 0.0223 acc: 0.6465
#
# Epoch [5000/20249] phase: validA train loss: 0.0059 acc: 2.3509 valid loss: 0.1823 acc: 0.2786
#
# Epoch [5000/20249] phase: validB train loss: 0.0158 acc: 2.0822 valid loss: 0.1569 acc: 0.2380
#
# Epoch [5000/20249] phase: validC train loss: 0.0056 acc: 2.3839 valid loss: 0.0262 acc: 0.6093
#
# Epoch [5250/20249] phase: validA train loss: 0.0058 acc: 2.3581 valid loss: 0.1981 acc: 0.2803
#
# Epoch [5250/20249] phase: validB train loss: 0.0153 acc: 2.1023 valid loss: 0.1654 acc: 0.2451
#
# Epoch [5250/20249] phase: validC train loss: 0.0054 acc: 2.3802 valid loss: 0.0222 acc: 0.6467
#
# Epoch [5500/20249] phase: validA train loss: 0.0055 acc: 2.3691 valid loss: 0.1976 acc: 0.2799
#
# Epoch [5500/20249] phase: validB train loss: 0.0152 acc: 2.1044 valid loss: 0.1588 acc: 0.2387
#
# Epoch [5500/20249] phase: validC train loss: 0.0051 acc: 2.3892 valid loss: 0.0224 acc: 0.6580
#
# Epoch [5750/20249] phase: validA train loss: 0.0053 acc: 2.3709 valid loss: 0.2029 acc: 0.2799
#
# Epoch [5750/20249] phase: validB train loss: 0.0145 acc: 2.1228 valid loss: 0.1585 acc: 0.2411
#
# Epoch [5750/20249] phase: validC train loss: 0.0047 acc: 2.3959 valid loss: 0.0237 acc: 0.6429
#
# Epoch [6000/20249] phase: validA train loss: 0.0054 acc: 2.3708 valid loss: 0.1888 acc: 0.2793
#
# Epoch [6000/20249] phase: validB train loss: 0.0140 acc: 2.1334 valid loss: 0.1732 acc: 0.2408
#
# Epoch [6000/20249] phase: validC train loss: 0.0044 acc: 2.4091 valid loss: 0.0241 acc: 0.6399
#
# Epoch [6250/20249] phase: validA train loss: 0.0048 acc: 2.3778 valid loss: 0.2076 acc: 0.2794
#
# Epoch [6250/20249] phase: validB train loss: 0.0137 acc: 2.1406 valid loss: 0.1716 acc: 0.2375
#
# Epoch [6250/20249] phase: validC train loss: 0.0043 acc: 2.4053 valid loss: 0.0261 acc: 0.6223
#
# Epoch [6500/20249] phase: validA train loss: 0.0047 acc: 2.3875 valid loss: 0.2032 acc: 0.2798
#
# Epoch [6500/20249] phase: validB train loss: 0.0132 acc: 2.1584 valid loss: 0.1754 acc: 0.2410
#
# Epoch [6500/20249] phase: validC train loss: 0.0041 acc: 2.4075 valid loss: 0.0244 acc: 0.6487
#
# Epoch [6750/20249] phase: validA train loss: 0.0046 acc: 2.3909 valid loss: 0.2046 acc: 0.2809
#
# Epoch [6750/20249] phase: validB train loss: 0.0127 acc: 2.1730 valid loss: 0.1737 acc: 0.2421
#
# Epoch [6750/20249] phase: validC train loss: 0.0041 acc: 2.4086 valid loss: 0.0282 acc: 0.6155
#
# Epoch [7000/20249] phase: validA train loss: 0.0043 acc: 2.3928 valid loss: 0.2315 acc: 0.2786
#
# Epoch [7000/20249] phase: validB train loss: 0.0124 acc: 2.1864 valid loss: 0.1895 acc: 0.2431
#
# Epoch [7000/20249] phase: validC train loss: 0.0040 acc: 2.4144 valid loss: 0.0266 acc: 0.6303
#
# Epoch [7250/20249] phase: validA train loss: 0.0043 acc: 2.3948 valid loss: 0.2249 acc: 0.2790
#
# Epoch [7250/20249] phase: validB train loss: 0.0121 acc: 2.1844 valid loss: 0.1795 acc: 0.2392
#
# Epoch [7250/20249] phase: validC train loss: 0.0035 acc: 2.4258 valid loss: 0.0243 acc: 0.6514
#
# Epoch [7500/20249] phase: validA train loss: 0.0040 acc: 2.4011 valid loss: 0.2231 acc: 0.2814
#
# Epoch [7500/20249] phase: validB train loss: 0.0116 acc: 2.2072 valid loss: 0.1876 acc: 0.2410
#
# Epoch [7500/20249] phase: validC train loss: 0.0036 acc: 2.4227 valid loss: 0.0245 acc: 0.6550
#
# Epoch [7750/20249] phase: validA train loss: 0.0037 acc: 2.4073 valid loss: 0.2124 acc: 0.2812
#
# Epoch [7750/20249] phase: validB train loss: 0.0113 acc: 2.2098 valid loss: 0.1917 acc: 0.2463
#
# Epoch [7750/20249] phase: validC train loss: 0.0033 acc: 2.4284 valid loss: 0.0258 acc: 0.6490
#
# Epoch [8000/20249] phase: validA train loss: 0.0039 acc: 2.4073 valid loss: 0.2265 acc: 0.2831
#
# Epoch [8000/20249] phase: validB train loss: 0.0109 acc: 2.2175 valid loss: 0.1909 acc: 0.2439
#
# Epoch [8000/20249] phase: validC train loss: 0.0031 acc: 2.4272 valid loss: 0.0256 acc: 0.6580
#
# Epoch [8250/20249] phase: validA train loss: 0.0036 acc: 2.4041 valid loss: 0.2265 acc: 0.2812
#
# Epoch [8250/20249] phase: validB train loss: 0.0107 acc: 2.2267 valid loss: 0.2012 acc: 0.2432
#
# Epoch [8250/20249] phase: validC train loss: 0.0029 acc: 2.4370 valid loss: 0.0277 acc: 0.6382
#
# Epoch [8500/20249] phase: validA train loss: 0.0032 acc: 2.4255 valid loss: 0.2284 acc: 0.2814
#
# Epoch [8500/20249] phase: validB train loss: 0.0103 acc: 2.2355 valid loss: 0.1979 acc: 0.2439
#
# Epoch [8500/20249] phase: validC train loss: 0.0029 acc: 2.4334 valid loss: 0.0257 acc: 0.6569
#
# Epoch [8750/20249] phase: validA train loss: 0.0031 acc: 2.4205 valid loss: 0.2197 acc: 0.2818
#
# Epoch [8750/20249] phase: validB train loss: 0.0099 acc: 2.2573 valid loss: 0.2069 acc: 0.2447
#
# Epoch [8750/20249] phase: validC train loss: 0.0030 acc: 2.4364 valid loss: 0.0289 acc: 0.6313
#
# Epoch [9000/20249] phase: validA train loss: 0.0033 acc: 2.4198 valid loss: 0.2310 acc: 0.2784
#
# Epoch [9000/20249] phase: validB train loss: 0.0097 acc: 2.2561 valid loss: 0.2060 acc: 0.2463
#
# Epoch [9000/20249] phase: validC train loss: 0.0027 acc: 2.4413 valid loss: 0.0278 acc: 0.6405
#
# Epoch [9250/20249] phase: validA train loss: 0.0029 acc: 2.4284 valid loss: 0.2234 acc: 0.2824
#
# Epoch [9250/20249] phase: validB train loss: 0.0091 acc: 2.2708 valid loss: 0.2308 acc: 0.2463
#
# Epoch [9250/20249] phase: validC train loss: 0.0026 acc: 2.4444 valid loss: 0.0268 acc: 0.6548
#
# Epoch [9500/20249] phase: validA train loss: 0.0027 acc: 2.4305 valid loss: 0.2320 acc: 0.2806
#
# Epoch [9500/20249] phase: validB train loss: 0.0091 acc: 2.2661 valid loss: 0.2106 acc: 0.2464
#
# Epoch [9500/20249] phase: validC train loss: 0.0028 acc: 2.4388 valid loss: 0.0294 acc: 0.6371
#
# Epoch [9750/20249] phase: validA train loss: 0.0026 acc: 2.4334 valid loss: 0.2263 acc: 0.2805
#
# Epoch [9750/20249] phase: validB train loss: 0.0085 acc: 2.2867 valid loss: 0.2198 acc: 0.2441
#
# Epoch [9750/20249] phase: validC train loss: 0.0027 acc: 2.4403 valid loss: 0.0280 acc: 0.6431
#
# Epoch [10000/20249] phase: validA train loss: 0.0026 acc: 2.4364 valid loss: 0.2349 acc: 0.2822
#
# Epoch [10000/20249] phase: validB train loss: 0.0086 acc: 2.2916 valid loss: 0.2173 acc: 0.2444
#
# Epoch [10000/20249] phase: validC train loss: 0.0026 acc: 2.4436 valid loss: 0.0312 acc: 0.6275
#
# Epoch [10250/20249] phase: validA train loss: 0.0026 acc: 2.4380 valid loss: 0.2327 acc: 0.2837
#
# Epoch [10250/20249] phase: validB train loss: 0.0082 acc: 2.2933 valid loss: 0.2177 acc: 0.2474
#
# Epoch [10250/20249] phase: validC train loss: 0.0027 acc: 2.4447 valid loss: 0.0286 acc: 0.6513
#
# Epoch [10500/20249] phase: validA train loss: 0.0023 acc: 2.4378 valid loss: 0.2351 acc: 0.2827
#
# Epoch [10500/20249] phase: validB train loss: 0.0080 acc: 2.3013 valid loss: 0.2143 acc: 0.2474
#
# Epoch [10500/20249] phase: validC train loss: 0.0028 acc: 2.4381 valid loss: 0.0296 acc: 0.6401
#
# Epoch [10750/20249] phase: validA train loss: 0.0022 acc: 2.4417 valid loss: 0.2510 acc: 0.2817
#
# Epoch [10750/20249] phase: validB train loss: 0.0076 acc: 2.3080 valid loss: 0.2220 acc: 0.2456
#
# Epoch [10750/20249] phase: validC train loss: 0.0024 acc: 2.4489 valid loss: 0.0274 acc: 0.6580
#
# Epoch [11000/20249] phase: validA train loss: 0.0023 acc: 2.4384 valid loss: 0.2430 acc: 0.2837
#
# Epoch [11000/20249] phase: validB train loss: 0.0074 acc: 2.3206 valid loss: 0.2330 acc: 0.2468
#
# Epoch [11000/20249] phase: validC train loss: 0.0022 acc: 2.4509 valid loss: 0.0301 acc: 0.6377
#
# Epoch [11250/20249] phase: validA train loss: 0.0020 acc: 2.4503 valid loss: 0.2521 acc: 0.2829
#
# Epoch [11250/20249] phase: validB train loss: 0.0070 acc: 2.3292 valid loss: 0.2469 acc: 0.2434
#
# Epoch [11250/20249] phase: validC train loss: 0.0023 acc: 2.4497 valid loss: 0.0283 acc: 0.6493
#
# Epoch [11500/20249] phase: validA train loss: 0.0019 acc: 2.4544 valid loss: 0.2542 acc: 0.2826
#
# Epoch [11500/20249] phase: validB train loss: 0.0068 acc: 2.3272 valid loss: 0.2414 acc: 0.2465
#
# Epoch [11500/20249] phase: validC train loss: 0.0023 acc: 2.4486 valid loss: 0.0324 acc: 0.6096
#
# Epoch [11750/20249] phase: validA train loss: 0.0021 acc: 2.4466 valid loss: 0.2433 acc: 0.2837
#
# Epoch [11750/20249] phase: validB train loss: 0.0067 acc: 2.3328 valid loss: 0.2497 acc: 0.2452
#
# Epoch [11750/20249] phase: validC train loss: 0.0022 acc: 2.4544 valid loss: 0.0256 acc: 0.6763
#
# Epoch [12000/20249] phase: validA train loss: 0.0018 acc: 2.4552 valid loss: 0.2557 acc: 0.2830
#
# Epoch [12000/20249] phase: validB train loss: 0.0067 acc: 2.3352 valid loss: 0.2352 acc: 0.2463
#
# Epoch [12000/20249] phase: validC train loss: 0.0022 acc: 2.4512 valid loss: 0.0306 acc: 0.6336
#
# Epoch [12250/20249] phase: validA train loss: 0.0016 acc: 2.4575 valid loss: 0.2488 acc: 0.2842
#
# Epoch [12250/20249] phase: validB train loss: 0.0062 acc: 2.3453 valid loss: 0.2364 acc: 0.2504
#
# Epoch [12250/20249] phase: validC train loss: 0.0021 acc: 2.4542 valid loss: 0.0315 acc: 0.6254
#
# Epoch [12500/20249] phase: validA train loss: 0.0018 acc: 2.4494 valid loss: 0.2423 acc: 0.2837
#
# Epoch [12500/20249] phase: validB train loss: 0.0059 acc: 2.3492 valid loss: 0.2445 acc: 0.2465
#
# Epoch [12500/20249] phase: validC train loss: 0.0021 acc: 2.4511 valid loss: 0.0295 acc: 0.6480
#
# Epoch [12750/20249] phase: validA train loss: 0.0019 acc: 2.4559 valid loss: 0.2572 acc: 0.2840
#
# Epoch [12750/20249] phase: validB train loss: 0.0056 acc: 2.3652 valid loss: 0.2425 acc: 0.2462
#
# Epoch [12750/20249] phase: validC train loss: 0.0022 acc: 2.4516 valid loss: 0.0293 acc: 0.6478
#
# Epoch [13000/20249] phase: validA train loss: 0.0016 acc: 2.4595 valid loss: 0.2661 acc: 0.2829
#
# Epoch [13000/20249] phase: validB train loss: 0.0056 acc: 2.3639 valid loss: 0.2536 acc: 0.2469
#
# Epoch [13000/20249] phase: validC train loss: 0.0021 acc: 2.4547 valid loss: 0.0293 acc: 0.6414
#
# Epoch [13250/20249] phase: validA train loss: 0.0015 acc: 2.4616 valid loss: 0.2624 acc: 0.2839
#
# Epoch [13250/20249] phase: validB train loss: 0.0053 acc: 2.3678 valid loss: 0.2651 acc: 0.2441
#
# Epoch [13250/20249] phase: validC train loss: 0.0020 acc: 2.4544 valid loss: 0.0291 acc: 0.6520
#
# Epoch [13500/20249] phase: validA train loss: 0.0017 acc: 2.4561 valid loss: 0.2574 acc: 0.2839
#
# Epoch [13500/20249] phase: validB train loss: 0.0053 acc: 2.3667 valid loss: 0.2437 acc: 0.2472
#
# Epoch [13500/20249] phase: validC train loss: 0.0020 acc: 2.4561 valid loss: 0.0318 acc: 0.6324
#
# Epoch [13750/20249] phase: validA train loss: 0.0014 acc: 2.4617 valid loss: 0.2707 acc: 0.2843
#
# Epoch [13750/20249] phase: validB train loss: 0.0051 acc: 2.3755 valid loss: 0.2420 acc: 0.2497
#
# Epoch [13750/20249] phase: validC train loss: 0.0020 acc: 2.4602 valid loss: 0.0320 acc: 0.6262
#
# Epoch [14000/20249] phase: validA train loss: 0.0013 acc: 2.4678 valid loss: 0.2680 acc: 0.2826
#
# Epoch [14000/20249] phase: validB train loss: 0.0048 acc: 2.3850 valid loss: 0.2460 acc: 0.2450
#
# Epoch [14000/20249] phase: validC train loss: 0.0018 acc: 2.4600 valid loss: 0.0312 acc: 0.6521
#
# Epoch [14250/20249] phase: validA train loss: 0.0013 acc: 2.4631 valid loss: 0.2684 acc: 0.2826
#
# Epoch [14250/20249] phase: validB train loss: 0.0046 acc: 2.3894 valid loss: 0.2539 acc: 0.2478
#
# Epoch [14250/20249] phase: validC train loss: 0.0017 acc: 2.4606 valid loss: 0.0321 acc: 0.6401
#
# Epoch [14500/20249] phase: validA train loss: 0.0014 acc: 2.4598 valid loss: 0.2744 acc: 0.2846
#
# Epoch [14500/20249] phase: validB train loss: 0.0047 acc: 2.3831 valid loss: 0.2622 acc: 0.2495
#
# Epoch [14500/20249] phase: validC train loss: 0.0018 acc: 2.4600 valid loss: 0.0311 acc: 0.6470
#
# Epoch [14750/20249] phase: validA train loss: 0.0013 acc: 2.4689 valid loss: 0.2669 acc: 0.2838
#
# Epoch [14750/20249] phase: validB train loss: 0.0047 acc: 2.3836 valid loss: 0.2599 acc: 0.2471
#
# Epoch [14750/20249] phase: validC train loss: 0.0018 acc: 2.4622 valid loss: 0.0283 acc: 0.6622
#
# Epoch [15000/20249] phase: validA train loss: 0.0013 acc: 2.4645 valid loss: 0.2771 acc: 0.2825
#
# Epoch [15000/20249] phase: validB train loss: 0.0043 acc: 2.3919 valid loss: 0.2720 acc: 0.2466
#
# Epoch [15000/20249] phase: validC train loss: 0.0018 acc: 2.4578 valid loss: 0.0312 acc: 0.6432
#
# Epoch [15250/20249] phase: validA train loss: 0.0012 acc: 2.4697 valid loss: 0.2669 acc: 0.2841
#
# Epoch [15250/20249] phase: validB train loss: 0.0039 acc: 2.4058 valid loss: 0.2674 acc: 0.2492
#
# Epoch [15250/20249] phase: validC train loss: 0.0019 acc: 2.4594 valid loss: 0.0296 acc: 0.6574
#
# Epoch [15500/20249] phase: validA train loss: 0.0011 acc: 2.4723 valid loss: 0.2723 acc: 0.2822
#
# Epoch [15500/20249] phase: validB train loss: 0.0038 acc: 2.4066 valid loss: 0.2744 acc: 0.2466
#
# Epoch [15500/20249] phase: validC train loss: 0.0018 acc: 2.4594 valid loss: 0.0321 acc: 0.6340
#
# Epoch [15750/20249] phase: validA train loss: 0.0009 acc: 2.4744 valid loss: 0.2877 acc: 0.2836
#
# Epoch [15750/20249] phase: validB train loss: 0.0039 acc: 2.4020 valid loss: 0.2661 acc: 0.2469
#
# Epoch [15750/20249] phase: validC train loss: 0.0018 acc: 2.4609 valid loss: 0.0316 acc: 0.6371
#
# Epoch [16000/20249] phase: validA train loss: 0.0011 acc: 2.4686 valid loss: 0.2752 acc: 0.2829
#
# Epoch [16000/20249] phase: validB train loss: 0.0040 acc: 2.3975 valid loss: 0.2777 acc: 0.2488
#
# Epoch [16000/20249] phase: validC train loss: 0.0018 acc: 2.4619 valid loss: 0.0307 acc: 0.6425
#
# Epoch [16250/20249] phase: validA train loss: 0.0009 acc: 2.4775 valid loss: 0.2707 acc: 0.2839
#
# Epoch [16250/20249] phase: validB train loss: 0.0037 acc: 2.4125 valid loss: 0.2701 acc: 0.2467
#
# Epoch [16250/20249] phase: validC train loss: 0.0016 acc: 2.4638 valid loss: 0.0354 acc: 0.6137
#
# Epoch [16500/20249] phase: validA train loss: 0.0010 acc: 2.4714 valid loss: 0.2810 acc: 0.2835
#
# Epoch [16500/20249] phase: validB train loss: 0.0037 acc: 2.4087 valid loss: 0.2745 acc: 0.2495
#
# Epoch [16500/20249] phase: validC train loss: 0.0016 acc: 2.4648 valid loss: 0.0280 acc: 0.6637
#
# Epoch [16750/20249] phase: validA train loss: 0.0009 acc: 2.4728 valid loss: 0.2780 acc: 0.2841
#
# Epoch [16750/20249] phase: validB train loss: 0.0033 acc: 2.4183 valid loss: 0.2949 acc: 0.2483
#
# Epoch [16750/20249] phase: validC train loss: 0.0017 acc: 2.4617 valid loss: 0.0337 acc: 0.6246
#
# Epoch [17000/20249] phase: validA train loss: 0.0008 acc: 2.4773 valid loss: 0.2877 acc: 0.2844
#
# Epoch [17000/20249] phase: validB train loss: 0.0035 acc: 2.4119 valid loss: 0.2831 acc: 0.2487
#
# Epoch [17000/20249] phase: validC train loss: 0.0018 acc: 2.4614 valid loss: 0.0310 acc: 0.6413
#
# Epoch [17250/20249] phase: validA train loss: 0.0010 acc: 2.4736 valid loss: 0.2835 acc: 0.2838
#
# Epoch [17250/20249] phase: validB train loss: 0.0032 acc: 2.4230 valid loss: 0.2727 acc: 0.2475
#
# Epoch [17250/20249] phase: validC train loss: 0.0013 acc: 2.4694 valid loss: 0.0322 acc: 0.6376
#
# Epoch [17500/20249] phase: validA train loss: 0.0009 acc: 2.4766 valid loss: 0.2890 acc: 0.2838
#
# Epoch [17500/20249] phase: validB train loss: 0.0032 acc: 2.4223 valid loss: 0.2844 acc: 0.2475
#
# Epoch [17500/20249] phase: validC train loss: 0.0017 acc: 2.4616 valid loss: 0.0324 acc: 0.6369
#
# Epoch [17750/20249] phase: validA train loss: 0.0009 acc: 2.4770 valid loss: 0.2840 acc: 0.2846
#
# Epoch [17750/20249] phase: validB train loss: 0.0030 acc: 2.4245 valid loss: 0.2724 acc: 0.2468
#
# Epoch [17750/20249] phase: validC train loss: 0.0015 acc: 2.4672 valid loss: 0.0291 acc: 0.6584
#
# Epoch [18000/20249] phase: validA train loss: 0.0007 acc: 2.4803 valid loss: 0.2897 acc: 0.2840
#
# Epoch [18000/20249] phase: validB train loss: 0.0029 acc: 2.4309 valid loss: 0.2851 acc: 0.2497
#
# Epoch [18000/20249] phase: validC train loss: 0.0016 acc: 2.4644 valid loss: 0.0355 acc: 0.6147
#
# Epoch [18250/20249] phase: validA train loss: 0.0008 acc: 2.4773 valid loss: 0.2903 acc: 0.2843
#
# Epoch [18250/20249] phase: validB train loss: 0.0027 acc: 2.4362 valid loss: 0.2782 acc: 0.2496
#
# Epoch [18250/20249] phase: validC train loss: 0.0016 acc: 2.4625 valid loss: 0.0290 acc: 0.6551
#
# Epoch [18500/20249] phase: validA train loss: 0.0007 acc: 2.4780 valid loss: 0.2851 acc: 0.2850
#
# Epoch [18500/20249] phase: validB train loss: 0.0028 acc: 2.4356 valid loss: 0.2904 acc: 0.2488
#
# Epoch [18500/20249] phase: validC train loss: 0.0015 acc: 2.4667 valid loss: 0.0278 acc: 0.6691
#
# Epoch [18750/20249] phase: validA train loss: 0.0008 acc: 2.4750 valid loss: 0.3006 acc: 0.2838
#
# Epoch [18750/20249] phase: validB train loss: 0.0029 acc: 2.4273 valid loss: 0.2825 acc: 0.2474
#
# Epoch [18750/20249] phase: validC train loss: 0.0017 acc: 2.4633 valid loss: 0.0355 acc: 0.6184
#
# Epoch [19000/20249] phase: validA train loss: 0.0007 acc: 2.4806 valid loss: 0.3036 acc: 0.2834
#
# Epoch [19000/20249] phase: validB train loss: 0.0029 acc: 2.4292 valid loss: 0.2899 acc: 0.2492
#
# Epoch [19000/20249] phase: validC train loss: 0.0016 acc: 2.4659 valid loss: 0.0326 acc: 0.6319
#
# Epoch [19250/20249] phase: validA train loss: 0.0007 acc: 2.4814 valid loss: 0.3029 acc: 0.2843
#
# Epoch [19250/20249] phase: validB train loss: 0.0025 acc: 2.4408 valid loss: 0.2879 acc: 0.2505
#
# Epoch [19250/20249] phase: validC train loss: 0.0015 acc: 2.4677 valid loss: 0.0318 acc: 0.6449
#
# Epoch [19500/20249] phase: validA train loss: 0.0007 acc: 2.4800 valid loss: 0.2987 acc: 0.2833
#
# Epoch [19500/20249] phase: validB train loss: 0.0025 acc: 2.4369 valid loss: 0.2929 acc: 0.2489
#
# Epoch [19500/20249] phase: validC train loss: 0.0014 acc: 2.4666 valid loss: 0.0320 acc: 0.6406

# %% [markdown]
# ## Testing ground

# %%
### Test funciton on conv layers

A = list(resnetA.named_parameters())[-14][1]
B = list(resnetB.named_parameters())[-14][1]
x = torch.cat((A, B), 1)
x.shape

pool = torch.nn.AdaptiveAvgPool2d(1)
inter = Interpolate(size=(1), mode='bilinear')

px = pool(x)
ix = inter(x)
